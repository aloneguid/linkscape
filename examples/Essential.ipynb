# %% [markdown]
# # Essential examples

# %%
from linkscape.network import Network

# %% [markdown]
# ## Nodes
#
# To start with, let's create a basic network with 3 nodes and 2 edges. First, create an instance of the Network class, specifying canvas size. Then, add nodes to the network.

# %%
g = Network(800, 200)

g.node("1")
g.node("2")
g.node("3")

g
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." width="800" height="200" scrolling="no" style="border:none !important;"></iframe>

# %% [markdown]
# `.node()` method returns `Node` object, which can be used to customize node properties.

# %%
g = Network(800, 100)
node = g.node("4")
node.label = "Node 4"
node.radius = 5
node.tooltip = "This is node 4"
node.color = "red"
node.stroke = "black"
node.stroke_width = 2
g
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." width="800" height="100" scrolling="no" style="border:none !important;"></iframe>

# %% [markdown]
# ## Edges
#
# To add edges to the network, use the `edge()` method. It takes two node ids as arguments, source node id and target node id.

# %%
g = Network(800, 200)
g.node("1")
g.node("2")
g.edge("1", "2")
g
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." width="800" height="200" scrolling="no" style="border:none !important;"></iframe>

# %% [markdown]
# `.edge()` method returns `Edge` object, which can be used to customize edge properties.

# %%
g.node("3")
edge = g.edge("2", "3")
edge.color = "black"
edge.opacity = 0.8
edge.width = 2
edge.label = "Edge 2-3"
edge.force = 0.01
g
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." width="800" height="200" scrolling="no" style="border:none !important;"></iframe>
